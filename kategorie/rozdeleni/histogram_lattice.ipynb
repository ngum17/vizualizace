# %%
# Measure the execution time of a code block
start.time <- Sys.time()

# Load the necessary libraries
library(lattice)

# load data stored in a CSV file
df <- read.csv("data/healthcare_dataset2.csv", sep=";")

# Set the plot size 
options(repr.plot.width=6, repr.plot.height=6)

# Define the age bins
age_bins <- cut(df$Age, breaks = seq(0, 100, by = 10))

# Create a histogram of ages with custom bins
histogram(~age_bins, 
          data = df, 
          main = "Histogram of Ages with Custom Bins", 
          xlab = "Age",
          ylab = "Frequency",
          col = "skyblue")

end.time <- Sys.time()
print(end.time - start.time)
# Out:
# Time difference of 0.9093769 secs
# plot without title
