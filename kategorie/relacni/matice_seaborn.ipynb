# %%
# %%time
# import necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# set seaborn style
sns.set_theme()

df = pd.read_csv("data/penguins.csv")

sns.pairplot(df, hue = "species", height=1.75)

plt.show()
# Out:
# CPU times: user 11.3 s, sys: 1e+03 ms, total: 12.3 s
# Wall time: 21.6 s
